# %%
import numpy as np

# %%
data=np.loadtxt('/Users/usuario-mac/Desktop/CLASES/2021-2/Logica/Taller/Taller3/notas.txt')

# %%
C1=data[:,0]
C2=data[:,1]
C3=data[:,2]

print(C1)
# Out:
# [3.61308802 1.8343876  2.8839956  2.37657535 4.13251166 1.65616595
#  0.32625482 3.86998321 0.35539663 2.76220496 2.44360174 4.82728183
#  0.28594625 1.99003588 1.9447606  3.73434363 2.69595744 0.98002072
#  4.52641496 2.18069425 4.22887118 3.472353   0.09928399 3.32714682
#  4.14482445 0.8426526  3.7993614  2.7885367  3.79265182 4.58119561]

# %%
Auto=(C1+C2+C3)/len(C1)
Co=(C1+C2+C3)/len(C1)

# %%
final=(C1*0.24)+(C2*0.24)+(C3*0.32)+(Auto*0.1)+(Co*0.1)
print(final)
# Out:
# [2.14045433 1.8624367  1.72505369 0.93054066 1.11658909 1.30650409
#  1.95594755 2.65718971 1.31908407 2.06221971 2.6879924  2.3468444
#  2.6304855  2.40681884 2.98365045 1.96275977 1.36979184 1.37230419
#  3.4329789  1.25459796 1.90080745 2.52953571 0.39277393 2.18175828
#  2.87240911 2.4895547  2.81509052 1.50208633 2.66077879 2.98027396]

# %%
j= final > 3.0
print(j[j],final[j])
# Out:
# [ True] [3.4329789]

# %%
import matplotlib.pyplot as plt
C1p=np.mean(C1)
C2p=np.mean(C2)
C3p=np.mean(C3)


plt.hist(C1p,label='C1')
plt.hist(C2p,label='C2')
plt.hist(C3p,label='C3')
plt.legend()
plt.show()

# %%
IDE=np.arange(0,len(C1))

plt.plot(IDE,C1,marker='o')
plt.xlabel('Codigo Estudiante')
plt.ylabel('Nota')
#plt.plot(IDE,C2,marker='o')
#plt.plot(IDE,C3,marker='o')
# Out:
# Text(0, 0.5, 'Nota')

# %%
#2.
def absoluto(a):
    a=np.array(a)
    if a!=0:
        print('cero')
        
    elif a==0:
        print('diferente')
    
    return a
    
    
absoluto([-2,-1,0,-3,-4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-15840293bd16> in <module>
#      11
#      12
# ---> 13 absoluto([-2,-1,0,-3,-4])
#
# <ipython-input-65-15840293bd16> in absoluto(a)
#       2 def absoluto(a):
#       3     a=np.array(a)
# ----> 4     if a!=0:
#       5         print('cero')
#       6
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
def absoluto(a):
    cero=a[0]
    for i in a:
        if i == 0:
            cero=0
            a=cero
        if i > 0:
            a=np.abs(a)
    return a

absoluto([-2,-1,0,-3,-4])
# Out:
# 0
